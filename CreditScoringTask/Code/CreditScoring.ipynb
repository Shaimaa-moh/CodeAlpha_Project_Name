# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
train_data= pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\train.csv')
test_data=pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\test.csv')
# Out:
# C:\Users\Shaima\AppData\Local\Temp\ipykernel_30764\2737183949.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data= pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\train.csv')

# %%
train_data.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
train_data.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
train_data.shape
# Out:
# (100000, 28)

# %%
train_data.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
train_data['Monthly_Inhand_Salary'].fillna(train_data['Monthly_Inhand_Salary'].mean(), inplace=True)
train_data['Type_of_Loan'].fillna(train_data['Type_of_Loan'].mode()[0], inplace=True)

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
train_data.isnull().sum()
# Out:
# ID                             0
# Customer_ID                    0
# Month                          0
# Name                        9985
# Age                            0
# SSN                            0
# Occupation                     0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                   0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      7002
# Changed_Credit_Limit           0
# Num_Credit_Inquiries        1965
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          9030
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4479
# Payment_Behaviour              0
# Monthly_Balance             1200
# Credit_Score                   0
# dtype: int64

# %%
drop_columns=['ID',"Customer_ID","Name","SSN","Credit_History_Age",'Payment_Behaviour',"Type_of_Loan","Age","Month"]
train1=train_data.drop(drop_columns,axis=1)

# %%
# Deleting (-) and (_) in Column
train1['Annual_Income'] = train1['Annual_Income'].str.replace('-','')
train1['Annual_Income'] = train1['Annual_Income'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Num_of_Loan'] = train1['Num_of_Loan'].str.replace('-','')
train1['Num_of_Loan'] = train1['Num_of_Loan'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].str.replace('-','0')
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].str.replace('_','0')

# Deleting (-) and (_) in Column
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].str.replace('-','')
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Monthly_Balance'] = train1['Monthly_Balance'].str.replace('-','')
train1['Monthly_Balance'] = train1['Monthly_Balance'].str.replace('_','')

# %%
train1['Annual_Income'] = train1['Annual_Income'].astype(float)
train1['Num_of_Loan'] = train1['Num_of_Loan'].astype(int)
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].astype(float)
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].astype(float)
train1['Monthly_Balance'] = train1['Monthly_Balance'].astype(float)

# %%
train1['Monthly_Balance']=train1['Monthly_Balance'].fillna(train1['Monthly_Balance'].mean())
train1['Num_Credit_Inquiries']=train1['Num_Credit_Inquiries'].fillna(train1['Num_Credit_Inquiries'].mean())

# %%
train1
# Out:
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0      Scientist      19114.12            1824.843333                  3
# 1      Scientist      19114.12            4194.170850                  3
# 2      Scientist      19114.12            4194.170850                  3
# 3      Scientist      19114.12            4194.170850                  3
# 4      Scientist      19114.12            1824.843333                  3
# ...          ...           ...                    ...                ...
# 99995   Mechanic      39628.99            3359.415833                  4
# 99996   Mechanic      39628.99            3359.415833                  4
# 99997   Mechanic      39628.99            3359.415833                  4
# 99998   Mechanic      39628.99            3359.415833                  4
# 99999   Mechanic      39628.99            3359.415833                  4
#
#        Num_Credit_Card  Interest_Rate Num_of_Loan  Delay_from_due_date  \
# ...
