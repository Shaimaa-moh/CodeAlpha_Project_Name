# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
train_data= pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\train.csv')
test_data=pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\test.csv')
# Out:
# C:\Users\Shaima\AppData\Local\Temp\ipykernel_34796\2737183949.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_data= pd.read_csv('D:\\DeepLearning\\CodeAlpha_Project_Name\\CreditScoringTask\\Dataset\\train.csv')

# %%
train_data.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
train_data.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# ...

# %%
train_data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
# ...

# %%
train_data.shape
# Out:
# (100000, 28)

# %%
train_data.duplicated().sum()
# Out:
# 0

# %%
train_data.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
train_data.dropna(axis=1, thresh=len(train_data)*0.7, inplace=True)  # Drop columns with more than 30% null values
train_data.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named df
# Selecting only numeric columns for simplicity
numeric_columns = train_data.select_dtypes(include=['float64', 'int64']).columns

# Calculate the first quartile (Q1) and third quartile (Q3) for all numeric columns
Q1 = train_data[numeric_columns].quantile(0.25)
Q3 = train_data[numeric_columns].quantile(0.75)

# Calculate the interquartile range (IQR) for all numeric columns
IQR = Q3 - Q1

# Define the lower and upper bounds to identify outliers for all numeric columns
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers for each column
outliers = train_data[(train_data[numeric_columns] < lower_bound) | (train_data[numeric_columns] > upper_bound)].any(axis=1)

# Display outliers
print("Outliers using IQR:")
print(train_data[outliers])
# Out:
# Outliers using IQR:
#             ID Customer_ID     Month             Name Age          SSN  \
# 10      0x1610  CUS_0x21b1     March  Rick Rothackerj  28  004-07-5839
# 40      0x163e  CUS_0x95ee   January               Np  31  612-70-8987
# 44      0x1642  CUS_0x95ee       May               Np  31  612-70-8987
# 45      0x1643  CUS_0x95ee      June               Np  31  612-70-8987
# 50      0x164c  CUS_0x284a     March           Nadiaq  34  411-51-0676
# ...        ...         ...       ...              ...  ..          ...
# 99960  0x25fb6  CUS_0x372c   January  Lucia Mutikanik  18  340-85-7301
# 99970  0x25fc4   CUS_0xf16     March   Maria Sheahanb  45  868-70-2218
# 99985  0x25fdb  CUS_0x8600  February   Sarah McBridec  28  031-35-0942
# 99993  0x25fe7  CUS_0x942c  February            Nicks  25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June            Nicks  25  078-73-5990
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
drop_columns=['ID',"Name","SSN",'Payment_Behaviour',"Type_of_Loan","Age","Month","Occupation",'Credit_Score']
train1=train_data.drop(drop_columns,axis=1)

# %%
# Impute outliers with the mean of the respective columns
train1 = train_data.copy()
train1[numeric_columns] = train1[numeric_columns].mask(outliers, train_data[numeric_columns].mean(),axis=0)
# Display the DataFrame with imputed outliers
print("DataFrame with imputed outliers:")
print(train1)
# Out:
# DataFrame with imputed outliers:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
# Deleting (-) and (_) in Column
train1['Annual_Income'] = train1['Annual_Income'].str.replace('-','')
train1['Annual_Income'] = train1['Annual_Income'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Num_of_Loan'] = train1['Num_of_Loan'].str.replace('-','')
train1['Num_of_Loan'] = train1['Num_of_Loan'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].str.replace('-','0')
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].str.replace('_','0')

# Deleting (-) and (_) in Column
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].str.replace('-','')
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].str.replace('_','')

# Deleting (-) and (_) in Column
train1['Monthly_Balance'] = train1['Monthly_Balance'].str.replace('-','')
train1['Monthly_Balance'] = train1['Monthly_Balance'].str.replace('_','')


# Deleting (-) and (_) in Column
train1['Num_of_Delayed_Payment'] = train1['Num_of_Delayed_Payment'].str.replace('-','')
train1['Num_of_Delayed_Payment'] = train1['Num_of_Delayed_Payment'].str.replace('_','')

train1['Amount_invested_monthly'] = train1['Amount_invested_monthly'].str.replace('-','')
train1['Amount_invested_monthly'] = train1['Amount_invested_monthly'].str.replace('_','')


train1['Credit_Mix'] = train1['Amount_invested_monthly'].str.replace('-','')
train1['Credit_Mix'] = train1['Amount_invested_monthly'].str.replace('_','')

# %%
train1['Annual_Income'] = train1['Annual_Income'].astype(float)
train1['Monthly_Inhand_Salary'] = train1['Monthly_Inhand_Salary'].astype(float)
train1['Num_Bank_Accounts'] = train1['Num_Bank_Accounts'].astype(int)
train1['Num_Credit_Card']=train1['Num_Credit_Card'].astype(int)
train1['Interest_Rate']=train1['Interest_Rate'].astype(int)
train1['Num_of_Loan'] = train1['Num_of_Loan'].astype(int)
train1['Delay_from_due_date']=train1['Delay_from_due_date'].astype(int)
train1['Num_of_Delayed_Payment'] = train1['Num_of_Delayed_Payment'].astype(float)
train1['Changed_Credit_Limit'] = train1['Changed_Credit_Limit'].astype(float)
#train1['Num_Credit_Inquiries'] = train1['Num_Credit_Inquiries'].astype(int)
train1['Outstanding_Debt'] = train1['Outstanding_Debt'].astype(float)
train1['Credit_Utilization_Ratio']=train1['Credit_Utilization_Ratio'].astype(float)
train1['Total_EMI_per_month']=train1['Total_EMI_per_month'].astype(float)
train1['Monthly_Balance'] = train1['Monthly_Balance'].astype(float)
train1['Amount_invested_monthly'] = train1['Amount_invested_monthly'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[320], line 3
#       1 train1['Annual_Income'] = train1['Annual_Income'].astype(float)
#       2 train1['Monthly_Inhand_Salary'] = train1['Monthly_Inhand_Salary'].astype(float)
# ----> 3 train1['Num_Bank_Accounts'] = train1['Num_Bank_Accounts'].astype(int)
#       4 train1['Num_Credit_Card']=train1['Num_Credit_Card'].astype(int)
#       5 train1['Interest_Rate']=train1['Interest_Rate'].astype(int)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named df
# Fill missing values in 'Num_of_Delayed_Payment' within each group separately
train1['Num_of_Delayed_Payment'] = train1.groupby('Customer_ID')['Num_of_Delayed_Payment'].transform(lambda x: x.fillna(x.mean()))
train1['Credit_History_Age'] = train1.groupby('Customer_ID')['Credit_History_Age'].transform(lambda x: x.fillna(x.mode()))
train1['Credit_Mix'] = train1.groupby('Customer_ID')['Credit_Mix'].transform(lambda x: x.fillna(x.mode()))
train1['Amount_invested_monthly'] = train1.groupby('Customer_ID')['Amount_invested_monthly'].transform(lambda x: x.fillna(x.mean()))
train1['Num_Credit_Inquiries'] = train1.groupby('Customer_ID')['Num_Credit_Inquiries'].transform(lambda x: x.fillna(x.mean()))
train1['Monthly_Inhand_Salary'].fillna(train1['Monthly_Inhand_Salary'].mean(), inplace=True)
# train1['Type_of_Loan'].fillna(train1['Type_of_Loan'].mode()[0], inplace=True)

# %%
numeric_columns = train_data.select_dtypes(include=['float64', 'int64']).columns
print(numeric_columns)
# Out:
# Index(['Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Delay_from_due_date', 'Num_Credit_Inquiries',
#        'Credit_Utilization_Ratio', 'Total_EMI_per_month'],
#       dtype='object')

# %%
# train1.drop('Customer_ID',axis=1,inplace=True)
# correlation_matrix = train1.corr()
# # Display correlation matrix
# print(correlation_matrix)

# %%
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Visualize correlation matrix using a heatmap
# plt.figure(figsize=(12, 10))
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
# plt.show()

# %%
# Check for NaN values before transformation
print("Null values before transformation:")
print(train1[['Num_of_Delayed_Payment', 'Credit_History_Age', 'Credit_Mix']].isnull().sum())

# Fill NaN values using transform
train1['Num_of_Delayed_Payment'] = train1.groupby('Customer_ID')['Num_of_Delayed_Payment'].transform(lambda x: x.fillna(x.mean()))
train1['Credit_History_Age'] = train1.groupby('Customer_ID')['Credit_History_Age'].transform(lambda x: x.fillna(x.mode().iloc[0]))  # Using iloc[0] to get the first mode if multiple modes exist
train1['Credit_Mix'] = train1.groupby('Customer_ID')['Credit_Mix'].transform(lambda x: x.fillna(x.mode().iloc[0]))

# Check for NaN values after transformation
=print("\nNull values after transformation:")
print(train1[['Num_of_Delayed_Payment', 'Credit_History_Age', 'Credit_Mix']].isnull().sum())
# Out:
# Null values before transformation:
# Num_of_Delayed_Payment    0
# Credit_History_Age        0
# Credit_Mix                0
# dtype: int64
#
# Null values after transformation:
# Num_of_Delayed_Payment    0
# Credit_History_Age        0
# Credit_Mix                0
# dtype: int64

# %%
train1 = train1.dropna(subset=['Monthly_Balance'])

# %%
train1.isnull().sum()
# Out:
# Customer_ID                 0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Monthly_Balance             0
# dtype: int64

# %%
train1
# Out:
#       Customer_ID  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0       CUS_0xd40       19114.12            1824.843333                  3
# 1       CUS_0xd40       19114.12            4194.170850                  3
# 2       CUS_0xd40       19114.12            4194.170850                  3
# 3       CUS_0xd40       19114.12            4194.170850                  3
# 4       CUS_0xd40       19114.12            1824.843333                  3
# ...           ...            ...                    ...                ...
# 99995  CUS_0x942c       39628.99            3359.415833                  4
# 99996  CUS_0x942c       39628.99            3359.415833                  4
# 99997  CUS_0x942c       39628.99            3359.415833                  4
# 99998  CUS_0x942c       39628.99            3359.415833                  4
# 99999  CUS_0x942c       39628.99            3359.415833                  4
#
# ...
